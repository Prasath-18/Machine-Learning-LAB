# %%
import pandas as pd

from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report



X, y = make_blobs(n_samples=200, centers=3, n_features=3)


df = pd.DataFrame(dict(x=X[:, 0], y=X[:, 1], label=y))


print("Top five Records\n\n")

df_top = df.head(5)
print(df_top)


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.40, random_state=0
)

model = LogisticRegression()

model.fit(X_train, y_train)

predicted = model.predict(X_test)

print("\n\nClassification Report")

report_lr = classification_report(y_test, predicted)

print(report_lr)
# Out:
# Top five Records
#
#
#           x         y  label
# 0  0.840209 -6.093955      0
# 1  0.264206 -3.188782      0
# 2 -6.921482 -0.634827      2
# 3  0.639564 -3.663989      0
# 4 -1.375358 -2.970030      0
#
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        33
#            2       1.00      1.00      1.00        22
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %%
from sklearn import linear_model
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNet
from sklearn.datasets import make_regression


X, y = make_regression(
    n_samples=50,
    n_features=1,
    noise=0.1,
    random_state=42
)

regr = linear_model.LinearRegression()
regr.fit(X, y)

print("------------ Linear Regression ------------")
print("Intercept:", regr.intercept_)
print("Coefficient:", regr.coef_)

print("\nScore of Linear Regression:")
print(regr.score(X, y))

print("\nAdjusted R Squared for Linear Regression Model:")
print(regr.score(X, y))


clf = RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1])
clf.fit(X, y)

print("\n------------ Ridge Regression ------------")
print("Ridge Intercept:", clf.intercept_)
print("Ridge Coefficients:", clf.coef_)

print("\nBest Alpha:", clf.alpha_)

print("\nScore of Ridge Regression:")
print(clf.score(X, y))

print("\nAdjusted R Squared for Ridge Regression Model:")
print(clf.score(X, y))


clf1 = linear_model.Lasso(alpha=0.1)
clf1.fit(X, y)

print("\n------------ Lasso Regression ------------")
print("Lasso Intercept:", clf1.intercept_)
print("Lasso Coefficients:", clf1.coef_)

print("\nScore of Lasso Regression:")
print(clf1.score(X, y))

print("\nAdjusted R Squared for Lasso Regression Model:")
print(clf1.score(X, y))


clf2 = ElasticNet(random_state=0)
clf2.fit(X, y)

print("\n------------ ElasticNet Regression ------------")
print("ElasticNet Intercept:", clf2.intercept_)
print("ElasticNet Coefficients:", clf2.coef_)

print("\nScore of ElasticNet Regression:")
print(clf2.score(X, y))

print("\nAdjusted R Squared for ElasticNet Regression Model:")
print(clf2.score(X, y))
# Out:
# ------------ Linear Regression ------------
# Intercept: 0.016080089267869635
# Coefficient: [14.10587454]
#
# Score of Linear Regression:
# 0.9999450044524462
#
# Adjusted R Squared for Linear Regression Model:
# 0.9999450044524462
#
# ------------ Ridge Regression ------------
# Ridge Intercept: 0.016005632402122938
# Ridge Coefficients: [14.10554431]
#
# Best Alpha: 0.001
#
# Score of Ridge Regression:
# 0.9999450039044304
#
# Adjusted R Squared for Ridge Regression Model:
# 0.9999450039044304
#
# ------------ Lasso Regression ------------
# Lasso Intercept: -0.010312654124900344
# Lasso Coefficients: [13.98882]
#
# Score of Lasso Regression:
# 0.9998761467419897
#
# Adjusted R Squared for Lasso Regression Model:
# 0.9998761467419897
#
# ------------ ElasticNet Regression ------------
# ElasticNet Intercept: -1.241386450250116
# ElasticNet Coefficients: [8.52888088]
#
# Score of ElasticNet Regression:
# 0.8436387404942873
#
# Adjusted R Squared for ElasticNet Regression Model:
# 0.8436387404942873

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error


df = pd.DataFrame({'Age' : [25,32,45,28,51],
                   'exp': [2,8,20,5,25],
                   'salary':[35000,60000,95000,45000,120000],
                   'bonus':[2000,5000,10000,3000,15000]})

x = df[['Age','exp','bonus']]
y= df['salary']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
print('mse:',mse)
print('mae:',mae)
# Out:
# mse: 24999999.999983337
# mae: 4999.999999998334
